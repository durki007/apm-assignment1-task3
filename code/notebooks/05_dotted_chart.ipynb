# %% [markdown]
# # 05 — Synchronization dotted chart (subtask d-vi)

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from olympic_transport.dotted_chart import main
main()
# Out:
# Saved figure → g:\apm\figures\dotted_chart_sync.png

# %%
from IPython.display import Image, display
from olympic_transport.config import FIGURES_DIR
display(Image(str(FIGURES_DIR / 'dotted_chart_sync.png')))
