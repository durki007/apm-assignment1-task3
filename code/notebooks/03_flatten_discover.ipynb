# %% [markdown]
# # 03 — Flatten and discover Petri nets N_ot_oa and N_ot_sync (subtasks d-iv, d-v)

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from olympic_transport.flatten_discover import main
main()
# Out:
# --- Flattening to object type: TravelTicket (N_ot_oa) ---
#   Flat log: 66 traces
#   Saved model  → g:\apm\models\N_ot_oa.pnml
#   Saved figure → g:\apm\figures\N_ot_oa.png
#   Visible transitions: ['IssueTravelTicket', 'ValidateAtPublicGate', 'BoardViaAccreditationLane']
#
# --- Flattening to object type: Passenger (N_ot_sync) ---
#   Flat log: 198 traces
#   Saved model  → g:\apm\models\N_ot_sync.pnml
#   Saved figure → g:\apm\figures\N_ot_sync.png
#   Visible transitions: ['AssignToDeparture', 'ValidateAtPublicGate', 'Depart', 'CreateGroupBooking', 'IssueTravelTicket', 'BoardViaAccreditationLane', 'CompleteJourney']

# %%
from IPython.display import Image, display
from olympic_transport.config import FIGURES_DIR
display(Image(str(FIGURES_DIR / 'N_ot_oa.png')))
display(Image(str(FIGURES_DIR / 'N_ot_sync.png')))
