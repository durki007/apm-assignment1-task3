# %% [markdown]
# # 04 — Discover OC Petri net N2 (subtask e)

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from olympic_transport.discover_ocpn import main
main()
# Out:
# Saved figure → g:\apm\figures\N2_ocpn.png
# Saved model  → g:\apm\models\N2_ocpn.svg

# %%
from IPython.display import Image, display
from olympic_transport.config import FIGURES_DIR
display(Image(str(FIGURES_DIR / 'N2_ocpn.png')))
